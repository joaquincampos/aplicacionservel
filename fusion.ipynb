# %%
import pandas as pd
pd.set_option("display.max_columns", 500)
import geopandas as gpd
from app import leer_datos

df, colegios = leer_datos()

# %%
df.head(1)
# Out:
#    Nro Región       Región    Circunscripción senatorial    Distrito  \
# 0           1  DE TARAPACA  CIRCUNSCRIPCION SENATORIAL 2  DISTRITO 2
#
#           Comuna Circunscripción electoral  \
# 0  ALTO HOSPICIO             ALTO HOSPICIO
#
#                                      Local  Mesa  Nro.Voto Opciones Selección  \
# 0  ANEXO DE COLEGIO SAN ANTONIO DE MATILLA    78       1.0  APRUEBO      None
#
#    Votos
# 0     87

# %%
df.Local.nunique()
# Out:
# 2755

# %%
colegios.sample(10)
# Out:
#         AGNO      RBD  DGV_RBD                                  NOM_RBD  \
# 7595  2021.0  25545.0      9.0    ESCUELA ESPECIAL PART. N_ 1850 TRALEN
# 8187  2021.0  26004.0      5.0                   ESCUELA ESP. RENACERES
# 5295  2021.0  15791.0      0.0  ESCUELA ESPECIAL DIFERENCIAL SAN ANDRES
# 2201  2021.0   5604.0      9.0                ESCUELA PEDRO DE VALDIVIA
# 7814  2021.0   8598.0      7.0                      COLEGIO ALTO PALENA
# 9646  2021.0   1868.0      6.0                       ESCUELA LA CHOCOTA
# 8094  2021.0  31149.0      9.0       ESCUELA ESPECIAL DE LENGUAJE KAORY
# 2359  2021.0   5855.0      6.0                  ESC. BASICA MUCO CHUREO
# 6863  2021.0  26361.0      3.0    ESC. ESP. EL PRINCIPITO DE LA FLORIDA
# 1921  2021.0   5770.0      3.0                     ESCUELA BASICA KOYAM
#
#       TIPO_SOST  COD_REG_RB NOM_REG_RB  COD_PRO_RB  COD_COM_RB  \
# 7595        1.0        13.0         RM       131.0     13122.0
# ...

# %%
colegios.NOM_RBD.nunique()
# Out:
# 10510
